# %% [markdown]
# <a href="https://colab.research.google.com/github/vibhanshuGaincafe/MuseTalk/blob/main/MuseTalk_jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone -b dev https://github.com/camenduru/MuseTalk
# %cd /content/MuseTalk

# !pip install -q diffusers==0.27.2 accelerate==0.28.0 omegaconf ffmpeg-python mmpose mmdet gradio
# !pip install -q https://github.com/camenduru/wheels/releases/download/colab2/mmcv-2.1.0-cp310-cp310-linux_x86_64.whl

# !apt -y install -qq aria2
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/dw-ll_ucoco.pth -d /content/MuseTalk/models/dwpose -o dw-ll_ucoco.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/dw-ll_ucoco_384.onnx -d /content/MuseTalk/models/dwpose -o dw-ll_ucoco_384.onnx
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/dw-ll_ucoco_384.pth -d /content/MuseTalk/models/dwpose -o dw-ll_ucoco_384.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/dw-mm_ucoco.pth -d /content/MuseTalk/models/dwpose -o dw-mm_ucoco.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/dw-ss_ucoco.pth -d /content/MuseTalk/models/dwpose -o dw-ss_ucoco.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/dw-tt_ucoco.pth -d /content/MuseTalk/models/dwpose -o dw-tt_ucoco.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/rtm-l_ucoco_256-95bb32f5_20230822.pth -d /content/MuseTalk/models/dwpose -o rtm-l_ucoco_256-95bb32f5_20230822.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/rtm-x_ucoco_256-05f5bcb7_20230822.pth -d /content/MuseTalk/models/dwpose -o rtm-x_ucoco_256-05f5bcb7_20230822.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/rtm-x_ucoco_384-f5b50679_20230822.pth -d /content/MuseTalk/models/dwpose -o rtm-x_ucoco_384-f5b50679_20230822.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/yolox_l.onnx -d /content/MuseTalk/models/dwpose -o yolox_l.onnx
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/face-parse-bisent/79999_iter.pth -d /content/MuseTalk/models/face-parse-bisent -o 79999_iter.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/face-parse-bisent/resnet18-5c106cde.pth -d /content/MuseTalk/models/face-parse-bisent -o resnet18-5c106cde.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/raw/main/musetalk/musetalk.json -d /content/MuseTalk/models/musetalk -o musetalk.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/musetalk/pytorch_model.bin -d /content/MuseTalk/models/musetalk -o pytorch_model.bin
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/raw/main/sd-vae-ft-mse/config.json -d /content/MuseTalk/models/sd-vae-ft-mse -o config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/sd-vae-ft-mse/diffusion_pytorch_model.bin -d /content/MuseTalk/models/sd-vae-ft-mse -o diffusion_pytorch_model.bin
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/sd-vae-ft-mse/diffusion_pytorch_model.safetensors -d /content/MuseTalk/models/sd-vae-ft-mse -o diffusion_pytorch_model.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/whisper/tiny.pt -d /content/MuseTalk/models/whisper -o tiny.pt

# !python app.py
# Out:
# /content
# Cloning into 'MuseTalk'...
# remote: Enumerating objects: 252, done.
# remote: Total 252 (delta 0), reused 0 (delta 0), pack-reused 252 (from 1)
# Receiving objects: 100% (252/252), 23.92 MiB | 17.61 MiB/s, done.
# Resolving deltas: 100% (71/71), done.
# /content/MuseTalk
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 43.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 26.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 80.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 85.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 117.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 93.9 MB/s eta 0:00:00
# ...

# %%
# 📁 Step 1: Clone the repo and move into it
# %cd /content
# !git clone -b dev https://github.com/camenduru/MuseTalk
# %cd /content/MuseTalk

# 🧩 Step 2: Install required Python packages
# !pip install -q diffusers==0.27.2 accelerate==0.28.0 omegaconf ffmpeg-python mmpose mmdet gradio
# !pip install -q huggingface_hub==0.15.1
# !pip install -q https://github.com/camenduru/wheels/releases/download/colab2/mmcv-2.1.0-cp310-cp310-linux_x86_64.whl

# 🧰 Step 3: Install aria2 to download model files
# !apt -y install -qq aria2

# 💾 Step 4: Download models and weights
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/dw-ll_ucoco.pth -d models/dwpose -o dw-ll_ucoco.pth
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/dw-ll_ucoco_384.onnx -d models/dwpose -o dw-ll_ucoco_384.onnx
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/dw-ll_ucoco_384.pth -d models/dwpose -o dw-ll_ucoco_384.pth
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/dw-mm_ucoco.pth -d models/dwpose -o dw-mm_ucoco.pth
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/dw-ss_ucoco.pth -d models/dwpose -o dw-ss_ucoco.pth
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/dw-tt_ucoco.pth -d models/dwpose -o dw-tt_ucoco.pth
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/rtm-l_ucoco_256-95bb32f5_20230822.pth -d models/dwpose -o rtm-l_ucoco_256-95bb32f5_20230822.pth
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/rtm-x_ucoco_256-05f5bcb7_20230822.pth -d models/dwpose -o rtm-x_ucoco_256-05f5bcb7_20230822.pth
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/rtm-x_ucoco_384-f5b50679_20230822.pth -d models/dwpose -o rtm-x_ucoco_384-f5b50679_20230822.pth
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/yolox_l.onnx -d models/dwpose -o yolox_l.onnx

# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/face-parse-bisent/79999_iter.pth -d models/face-parse-bisent -o 79999_iter.pth
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/face-parse-bisent/resnet18-5c106cde.pth -d models/face-parse-bisent -o resnet18-5c106cde.pth

# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/raw/main/musetalk/musetalk.json -d models/musetalk -o musetalk.json
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/musetalk/pytorch_model.bin -d models/musetalk -o pytorch_model.bin

# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/raw/main/sd-vae-ft-mse/config.json -d models/sd-vae-ft-mse -o config.json
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/sd-vae-ft-mse/diffusion_pytorch_model.bin -d models/sd-vae-ft-mse -o diffusion_pytorch_model.bin
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/sd-vae-ft-mse/diffusion_pytorch_model.safetensors -d models/sd-vae-ft-mse -o diffusion_pytorch_model.safetensors

# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/whisper/tiny.pt -d models/whisper -o tiny.pt

# 🎬 Step 5: Download and set static ffmpeg path
# !aria2c -x 16 -s 16 https://www.gyan.dev/ffmpeg/builds/ffmpeg-release-amd64-static.tar.xz -d /content -o ffmpeg.tar.xz
# !tar -xf /content/ffmpeg.tar.xz -C /content
import os, glob
ffmpeg_dirs = glob.glob("/content/ffmpeg-*")
os.environ["FFMPEG_PATH"] = ffmpeg_dirs[0]
print("✅ FFMPEG_PATH set to:", os.environ["FFMPEG_PATH"])

# 🚀 Step 6: Run the app
# !python app.py
# Out:
# /content
# fatal: destination path 'MuseTalk' already exists and is not an empty directory.
# /content/MuseTalk
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 6.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# diffusers 0.27.2 requires huggingface-hub>=0.20.2, but you have huggingface-hub 0.15.1 which is incompatible.
# transformers 4.52.4 requires huggingface-hub<1.0,>=0.30.0, but you have huggingface-hub 0.15.1 which is incompatible.
# gradio-client 1.10.1 requires huggingface-hub>=0.19.3, but you have huggingface-hub 0.15.1 which is incompatible.
# sentence-transformers 4.1.0 requires huggingface-hub>=0.20.0, but you have huggingface-hub 0.15.1 which is incompatible.
# gradio 5.31.0 requires huggingface-hub>=0.28.1, but you have huggingface-hub 0.15.1 which is incompatible.
# ...

# %%
# 📁 Step 1: Clone the repo and move into it
# %cd /content
# !git clone -b dev https://github.com/camenduru/MuseTalk
# %cd /content/MuseTalk

# 🧩 Step 2: Install required Python packages
# !pip install -q diffusers==0.27.2 accelerate==0.28.0 omegaconf ffmpeg-python mmpose mmdet gradio
# !pip install -q huggingface_hub==0.15.1
# !pip install -q https://github.com/camenduru/wheels/releases/download/colab2/mmcv-2.1.0-cp310-cp310-linux_x86_64.whl

# 🧰 Step 3: Install aria2 to download model files
# !apt -y install -qq aria2

# 💾 Step 4: Download models and weights
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/dw-ll_ucoco.pth -d models/dwpose -o dw-ll_ucoco.pth
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/dw-ll_ucoco_384.onnx -d models/dwpose -o dw-ll_ucoco_384.onnx
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/dw-ll_ucoco_384.pth -d models/dwpose -o dw-ll_ucoco_384.pth
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/dw-mm_ucoco.pth -d models/dwpose -o dw-mm_ucoco.pth
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/dw-ss_ucoco.pth -d models/dwpose -o dw-ss_ucoco.pth
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/dw-tt_ucoco.pth -d models/dwpose -o dw-tt_ucoco.pth
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/rtm-l_ucoco_256-95bb32f5_20230822.pth -d models/dwpose -o rtm-l_ucoco_256-95bb32f5_20230822.pth
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/rtm-x_ucoco_256-05f5bcb7_20230822.pth -d models/dwpose -o rtm-x_ucoco_256-05f5bcb7_20230822.pth
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/rtm-x_ucoco_384-f5b50679_20230822.pth -d models/dwpose -o rtm-x_ucoco_384-f5b50679_20230822.pth
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/yolox_l.onnx -d models/dwpose -o yolox_l.onnx

# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/face-parse-bisent/79999_iter.pth -d models/face-parse-bisent -o 79999_iter.pth
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/face-parse-bisent/resnet18-5c106cde.pth -d models/face-parse-bisent -o resnet18-5c106cde.pth

# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/raw/main/musetalk/musetalk.json -d models/musetalk -o musetalk.json
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/musetalk/pytorch_model.bin -d models/musetalk -o pytorch_model.bin

# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/raw/main/sd-vae-ft-mse/config.json -d models/sd-vae-ft-mse -o config.json
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/sd-vae-ft-mse/diffusion_pytorch_model.bin -d models/sd-vae-ft-mse -o diffusion_pytorch_model.bin
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/sd-vae-ft-mse/diffusion_pytorch_model.safetensors -d models/sd-vae-ft-mse -o diffusion_pytorch_model.safetensors

# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/whisper/tiny.pt -d models/whisper -o tiny.pt

# 🎬 Step 5: Download and set static ffmpeg path
# Download ffmpeg
# !aria2c -x 16 -s 16 https://www.gyan.dev/ffmpeg/builds/ffmpeg-release-amd64-static.tar.xz -d /content -o ffmpeg.tar.xz

# Check if the download was successful
import os
if not os.path.exists("/content/ffmpeg.tar.xz"):
    raise FileNotFoundError("FFmpeg archive not downloaded successfully.")

# Extract ffmpeg
# !tar -xf /content/ffmpeg.tar.xz -C /content

# Find the extracted directory
import glob
ffmpeg_dirs = glob.glob("/content/ffmpeg-*")

# Check if the directory was found
if not ffmpeg_dirs:
    raise FileNotFoundError("FFmpeg directory not found after extraction.")

# Set the environment variable
os.environ["FFMPEG_PATH"] = ffmpeg_dirs[0]
print("✅ FFMPEG_PATH set to:", os.environ["FFMPEG_PATH"])

# 🚀 Step 6: Run the app
# !python app.py
# Out:
# /content
# fatal: destination path 'MuseTalk' already exists and is not an empty directory.
# /content/MuseTalk
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.1/512.1 kB 14.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# diffusers 0.27.2 requires huggingface-hub>=0.20.2, but you have huggingface-hub 0.15.1 which is incompatible.
# transformers 4.52.4 requires huggingface-hub<1.0,>=0.30.0, but you have huggingface-hub 0.15.1 which is incompatible.
# gradio-client 1.10.1 requires huggingface-hub>=0.19.3, but you have huggingface-hub 0.15.1 which is incompatible.
# sentence-transformers 4.1.0 requires huggingface-hub>=0.20.0, but you have huggingface-hub 0.15.1 which is incompatible.
# gradio 5.31.0 requires huggingface-hub>=0.28.1, but you have huggingface-hub 0.15.1 which is incompatible.
# ...

# %%
# 📁 Step 1: Clone the repo and move into it
# %cd /content
# !git clone -b dev https://github.com/camenduru/MuseTalk
# %cd /content/MuseTalk

# 🧩 Step 2: Install required Python packages
# !pip install -q diffusers==0.27.2 accelerate==0.28.0 omegaconf ffmpeg-python mmpose mmdet gradio
# !pip install -q huggingface_hub==0.15.1
# !pip install -q https://github.com/camenduru/wheels/releases/download/colab2/mmcv-2.1.0-cp310-cp310-linux_x86_64.whl

# 🧰 Step 3: Install aria2 to download model files
# !apt -y install -qq aria2

# 💾 Step 4: Download models and weights
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/dw-ll_ucoco.pth -d models/dwpose -o dw-ll_ucoco.pth
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/dw-ll_ucoco_384.onnx -d models/dwpose -o dw-ll_ucoco_384.onnx
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/dw-ll_ucoco_384.pth -d models/dwpose -o dw-ll_ucoco_384.pth
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/dw-mm_ucoco.pth -d models/dwpose -o dw-mm_ucoco.pth
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/dw-ss_ucoco.pth -d models/dwpose -o dw-ss_ucoco.pth
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/dw-tt_ucoco.pth -d models/dwpose -o dw-tt_ucoco.pth
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/rtm-l_ucoco_256-95bb32f5_20230822.pth -d models/dwpose -o rtm-l_ucoco_256-95bb32f5_20230822.pth
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/rtm-x_ucoco_256-05f5bcb7_20230822.pth -d models/dwpose -o rtm-x_ucoco_256-05f5bcb7_20230822.pth
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/rtm-x_ucoco_384-f5b50679_20230822.pth -d models/dwpose -o rtm-x_ucoco_384-f5b50679_20230822.pth
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/dwpose/yolox_l.onnx -d models/dwpose -o yolox_l.onnx

# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/face-parse-bisent/79999_iter.pth -d models/face-parse-bisent -o 79999_iter.pth
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/face-parse-bisent/resnet18-5c106cde.pth -d models/face-parse-bisent -o resnet18-5c106cde.pth

# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/raw/main/musetalk/musetalk.json -d models/musetalk -o musetalk.json
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/musetalk/pytorch_model.bin -d models/musetalk -o pytorch_model.bin

# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/raw/main/sd-vae-ft-mse/config.json -d models/sd-vae-ft-mse -o config.json
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/sd-vae-ft-mse/diffusion_pytorch_model.bin -d models/sd-vae-ft-mse -o diffusion_pytorch_model.bin
# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/sd-vae-ft-mse/diffusion_pytorch_model.safetensors -d models/sd-vae-ft-mse -o diffusion_pytorch_model.safetensors

# !aria2c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MuseTalk/resolve/main/whisper/tiny.pt -d models/whisper -o tiny.pt

# 🎬 Step 5: Download and set static ffmpeg path
# Download ffmpeg with error logging
# !aria2c --console-log-level=error -x 16 -s 16 https://www.gyan.dev/ffmpeg/builds/ffmpeg-release-amd64-static.tar.xz -d /content -o ffmpeg.tar.xz

# Check if the download was successful
import os
if not os.path.exists("/content/ffmpeg.tar.xz"):
    raise FileNotFoundError("FFmpeg archive not downloaded successfully. Check aria2c output for errors.")

# Extract ffmpeg
# !tar -xf /content/ffmpeg.tar.xz -C /content

# Find the extracted directory
import glob
ffmpeg_dirs = glob.glob("/content/ffmpeg-*")

# Check if the directory was found
if not ffmpeg_dirs:
    raise FileNotFoundError("FFmpeg directory not found after extraction.")

# Set the environment variable
os.environ["FFMPEG_PATH"] = ffmpeg_dirs[0]
print("✅ FFMPEG_PATH set to:", os.environ["FFMPEG_PATH"])

# 🚀 Step 6: Run the app
# !python app.py
# Out:
# /content
# fatal: destination path 'MuseTalk' already exists and is not an empty directory.
# /content/MuseTalk
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# diffusers 0.27.2 requires huggingface-hub>=0.20.2, but you have huggingface-hub 0.15.1 which is incompatible.
# transformers 4.52.4 requires huggingface-hub<1.0,>=0.30.0, but you have huggingface-hub 0.15.1 which is incompatible.
# gradio-client 1.10.1 requires huggingface-hub>=0.19.3, but you have huggingface-hub 0.15.1 which is incompatible.
# sentence-transformers 4.1.0 requires huggingface-hub>=0.20.0, but you have huggingface-hub 0.15.1 which is incompatible.
# gradio 5.31.0 requires huggingface-hub>=0.28.1, but you have huggingface-hub 0.15.1 which is incompatible.
# peft 0.15.2 requires huggingface_hub>=0.25.0, but you have huggingface-hub 0.15.1 which is incompatible.
# ...
